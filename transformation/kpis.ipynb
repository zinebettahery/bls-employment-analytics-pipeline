# %%
from pyspark.sql import functions as F
import pandas as pd

DELTA_PATH = "dbfs:/Volumes/bls_cew/silver/silver_cew/cleaned_data"

# Read with Spark
df_spark = spark.read.format("delta").load(DELTA_PATH)

# Convert to Pandas
df = df_spark.toPandas()

# Afficher avec Pandas
print(df.shape)
print(df.dtypes)
